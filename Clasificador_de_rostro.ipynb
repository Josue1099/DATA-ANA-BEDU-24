# %% [markdown]
# <a href="https://colab.research.google.com/github/Josue1099/DATA-ANA-BEDU-24/blob/main/Clasificador_de_rostro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

FILENAME = '/content/Screenshot 2024-09-02 at 9.33.03 p.m..png'
# Crear clasificador de rostros
clasificador_rostros = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)

import cv2
from google.colab.patches import cv2_imshow

FILENAME = '/content/Screenshot 2024-09-02 at 9.33.03 p.m..png'

# Crear clasificador de rostros
clasificador_rostros = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)

# Cargar la imagen
imagen = cv2.imread(FILENAME)

# Convertir la imagen original a escala de grises
imagen_gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)

# Detectar rostros con el clasificador
rostros = clasificador_rostros.detectMultiScale(
    imagen_gris,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 20)
)

# Dibujar rectángulos alrededor de los rostros detectados
for (x, y, w, h) in rostros:
    cv2.rectangle(imagen, (x, y), (x+w, y+h), (255, 0, 0), 2)

# Mostrar la imagen con rostros detectados
cv2_imshow(imagen)
# Out:
# <PIL.Image.Image image mode=RGB size=1219x890>
